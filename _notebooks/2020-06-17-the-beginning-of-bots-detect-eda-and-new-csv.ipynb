# %% [markdown]
# # Bots Detection the beginning

# %% [markdown]
# <h1> Welcome to my kernel. I have processed some columns to get better meaning of them including the user_agent strings and I have created new csv file containing the parsed UA as it took time in parsing so I did not want others to waste their time on parsing it :D</h1>
# <h1>Please do upvote if you find this kernel helpful or else just upvote :D</h1>
#
# <h1><a href="https://www.kaggle.com/omegaji/bots-ua-parsed">THE NEW DATA CREATED CAN BE FOUND HERE YOU CAN USE IT IN YOUR KERNELS!!  </a></h1>

# %% [markdown]
# <h1>List of Contents</h1>
# <ul>
#     <li><a href="#os_ext">Os Name Extraction and shortening/Grouping</a></li>
#         <li><a href="#views_visits">Plotting User views and visits</a></li>
#         <li><a href="#what_ua">What are user agents?</a></li>
#     <li><a href="#dd">Parsing User Agent String with DeviceDetector</a></li>
#         <li><a href="#first_half">Parsing The first half sample</a></li>
#         <li><a href="#is_bot">Detecting Bot or not from user agent</a></li>
#         <li><a href="#plot_is_bot">we plot how many bots are from which os</a></li>
#             <li><a href="#is_bot_browser">we plot how many bots are from which browser</a></li>
#         <li><a href="#tocsv1">Convert the first half of the data to csv </a></li>
#             <li><a href="#secondhalf">Convert the second half </a></li>
#         <li><a href="#big">Concatenate both and final dataframe savse as csv  </a></li>
#             <li><a href="#conclusion">Future work?  </a></li>
#
#
#
#
#
#
#
# </ul>

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 5GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/bot-detection/ibm_data.csv

# %%
df=pd.read_csv("/kaggle/input/bot-detection/ibm_data.csv")
df
# Out:
#          Unnamed: 0      ctry_name intgrtd_mngmt_name  \
# 0                 0  United States      United States
# 1                 1          Japan              Japan
# 2                 2  United States      United States
# 3                 3         Brazil             Brazil
# 4                 4         France             France
# ...             ...            ...                ...
# 1048568     1048568  United States      United States
# 1048569     1048569      Australia       Australia/NZ
# 1048570     1048570  United States      United States
# 1048571     1048571          Japan              Japan
# 1048572     1048572  United States      United States
#
#         intgrtd_operating_team_name                    city               st  \
# 0                     North America                 SLIDELL        LOUISIANA
# 1                             Japan                   TOKYO            TOKYO
# 2                     North America               ELK GROVE       CALIFORNIA
# 3                     Latin America  SAO FRANCISCO DE GOIAS            GOIAS
# 4                            Europe                  BEZONS       VAL-D'OISE
# ...                             ...                     ...              ...
# 1048568               North America               CUPERTINO       CALIFORNIA
# 1048569                Asia Pacific                  SYDNEY  NEW SOUTH WALES
# 1048570               North America               CLEVELAND             OHIO
# 1048571                       Japan              CHIYODA-KU            TOKYO
# 1048572               North America                 CHICAGO         ILLINOIS
#
#                 sec_lvl_domn  device_type         operating_sys  \
# 0                CHARTER.COM  MOBILEPHONE            IOS_12.1.4
# 1                 MOPERA.NET       TABLET           ANDROID_6.0
# 2        COMCASTBUSINESS.NET  MOBILEPHONE            IOS_12.1.2
# 3             VIVOZAP.COM.BR  MOBILEPHONE           ANDROID_6.0
# 4                 PROXAD.NET  MOBILEPHONE             ANDROID_9
# ...                      ...          ...                   ...
# 1048568                  NaN          NaN  MACINTOSH_OS X 10.14
# 1048569      OPTUSNET.COM.AU          NaN  MACINTOSH_OS X 10.13
# 1048570           PARKER.COM          NaN   MICROSOFT_WINDOWS10
# 1048571     ARGO-GRAPH.CO.JP          NaN   MICROSOFT_WINDOWS10
# 1048572                  NaN          NaN   MICROSOFT_WINDOWS10
#
#                                                    ip_addr  \
# 0        287e8e9aeedb50e963906f10cca7ca26ae830154e69220...
# 1        d7746df5cc2de7f79584d57c2c082b9acc7697602021a1...
# 2        8540464f5f376c7a160d63632f8cbedc96c61158daf9ae...
# 3        cb9ffa7be250fc62426a431a4f08bc0c8222f63514ba39...
# 4        7ce278be1b02a0253cc0219fa9ceddfe8e91846be343a4...
# ...                                                    ...
# 1048568  e37ade1326801a855c9b2d1bdb1f84399547c27178a7e7...
# 1048569  e926236cbc5da5db8bad29cdbb3537b867aa26e73a5f79...
# 1048570  3440973e4b965b19fa7e67b02c10ecb1d6ccc3c62e0d92...
# 1048571  0ff0318b41d99bf2240173368a7d861ef512a85d0abf15...
# 1048572  1d2922b3be5a885203c932991051bfc9269596e700e51b...
#
#                                                 user_agent  VISIT  ENGD_VISIT  \
# 0        MOZILLA/5.0 (IPHONE; CPU IPHONE OS 12_1_4 LIKE...      1           0
# 1        MOZILLA/5.0 (LINUX; ANDROID 6.0; D-01J BUILD/H...      1           0
# 2        MOZILLA/5.0 (IPHONE; CPU IPHONE OS 12_1_2 LIKE...      1           0
# 3        MOZILLA/5.0 (LINUX; ANDROID 6.0; PT-BR; 5010E ...      1           0
# 4        MOZILLA/5.0 (LINUX; ANDROID 9; SM-G965F BUILD/...      1           0
# ...                                                    ...    ...         ...
# 1048568  MOZILLA/5.0 (MACINTOSH; INTEL MAC OS X 10_14_2...      1           0
# 1048569  MOZILLA/5.0 (MACINTOSH; INTEL MAC OS X 10_13_1...      1           0
# 1048570  MOZILLA/5.0 (WINDOWS NT 10.0; WIN64; X64) APPL...      1           1
# 1048571  MOZILLA/5.0 (WINDOWS NT 10.0; WIN64; X64) APPL...      1           1
# 1048572  MOZILLA/5.0 (WINDOWS NT 10.0; WOW64) APPLEWEBK...      1           0
#
#          VIEWS                                           page_url  wk  mth  \
# 0            1                        www.ibm.com/watson/campaign  11    3
# 1            1                          www.ibm.com/privacy/us/en  11    3
# 2            1  www.ibm.com/account/reg/us-en/signup?formid=ur...  11    3
# 3            1  www.ibm.com/analytics/br/pt/business-intelligence  11    3
# 4            1                           www.ibm.com/watson/fr-fr  11    3
# ...        ...                                                ...  ..  ...
# 1048568      1  www.ibm.com/talent-management/news/talent-acqu...  11    3
# 1048569      1                    www.ustream.tv/channel/nba4live  11    3
# 1048570      1  www.ibm.com/support/knowledgecenter/en/search/...  11    3
# 1048571      1         www-945.ibm.com/support/fixcentral/options  11    3
# 1048572      1  www.ibm.com/support/knowledgecenter/en/ssepgg_...  11    3
#
#            yr                  page_vw_ts
# 0        2019  2019-06-04 05:05:18.023100
# 1        2019  2019-06-04 05:07:11.014300
# 2        2019  2019-06-04 05:08:46.081900
# 3        2019  2019-06-04 05:07:22.033300
# 4        2019  2019-06-04 05:05:27.027700
# ...       ...                         ...
# 1048568  2019  2019-06-04 13:27:37.059600
# 1048569  2019  2019-06-04 13:27:04.035100
# 1048570  2019  2019-06-04 13:40:47.060500
# 1048571  2019  2019-06-04 13:22:12.001900
# 1048572  2019  2019-06-04 13:39:50.074200
#
# [1048573 rows x 19 columns]

# %% [markdown]
# <h3>checking for nulls in operating systems column and replacing them with notgiven, we then find out the unique values of this column</h3>

# %%
print(df.operating_sys.isnull().sum())
df.operating_sys.fillna("NotGiven",inplace=True)
print(df.operating_sys.unique())
# Out:
# 1820
# ['IOS_12.1.4' 'ANDROID_6.0' 'IOS_12.1.2' 'ANDROID_9' 'ANDROID_8.0.0'
#  'IOS_12.1' 'IOS_11.3' 'IOS_12.1.1' 'ANDROID_8.1.0' 'MICROSOFT_WINDOWS10'
#  'ANDROID_7.0' 'ANDROID_7.1.1' 'MICROSOFT_WINDOWS7' 'ANDROID_5.1.1'
#  'ANDROID_8.0' 'ANDROID_7.1.2' 'MACINTOSH_OS X 10.12'
#  'MACINTOSH_OS X 10.14' 'MICROSOFT_WINDOWS8.1' 'IOS_9.3.5'
#  'MACINTOSH_OS X 10.13' 'LINUX' 'ANDROID_5.0.2' 'ANDROID_6.0.1' 'CHROMEOS'
#  'MICROSOFT_WINDOWS8' 'MACINTOSH_OS X 10.11' 'OTHER' 'IOS_12.0'
#  'IOS_12.0.1' 'MICROSOFT_WINXP' 'IOS_11.4.1' 'IOS_10.2' 'ANDROID_5.1'
#  'IOS_11.2.5' 'IOS_11.2.2' 'NotGiven' 'IOS_11.4' 'MACINTOSH_OS X 10.10'
#  'ANDROID_2.3.4' 'ANDROID_4.2.2' 'IOS_11.0.3' 'ANDROID_8.1' 'IOS_10.3.3'
#  'ANDROID_4.4.4' 'ANDROID_4.3' 'IOS_12.2' 'ANDROID_4.4.2' 'IOS_10.0.1'
#  'IOS_12.1.3' 'ANDROID_4.1.2' 'IOS_11.2.1' 'MACINTOSH_OS X 10.7' 'NETCAST'
#  'MACINTOSH_OS X 10.8' 'IOS_9.3.2' 'ANDROID_4.0.4' 'IOS_9.2.1'
#  'IOS_11.2.6' 'IOS_11.0.1' 'MACINTOSH_OS X 10.9' 'MICROSOFT_WINVISTA'
#  'IOS_9.1' 'MACINTOSH_OS X 10.4' 'MICROSOFT_WINNT' 'ANDROID_5.0.1'
#  'ANDROID_9.0' 'ANDROID_4.0.3' 'IOS_11.1.2' 'IOS_10.2.1' 'IOS_10.0.2'
#  'IOS_10.3.2' 'MACINTOSH_OS X 10.6' 'ANDROID_4.4.3' 'IOS_11.0.2'
#  'IOS_10.1.1' 'SONY PROPRIETARY' 'ANDROID_5.0' 'IOS_11.1'
#  'WINDOWSPHONE_8.1' 'IOS_9.0.2' 'IOS_9.2' 'IOS_10.3.1' 'IOS_11.0'
#  'IOS_10.1' 'IOS_10.0.3' 'IOS_8.0.2' 'RIMOS_BB10' 'IOS_8.0' 'UNIX'
#  'IOS_7.1' 'SUNOSI86PC' 'IOS_9.3' 'FREEBSD' 'IOS_10.3' 'IOS_11.1.1'
#  'ANDROID_4.4' 'IOS_3.2' 'IOS_9.3.4' 'ANDROID' 'IOS_11.2'
#  'MICROSOFT_WIN98' 'IOS_9.3.3' 'ANDROID_4.2.1' 'IOS_5.0' 'OS/2_OS/2'
#  'IOS_5.0.1' 'IOS' 'ANDROID_7.0.0' 'IOS_9.3.1' 'IOS_4' 'WINDOWSPHONE_10.0'
#  'RIMOS_6.0.0.546' 'IOS_5.1' 'IOS_7.0.4' 'ANDROID_9.0.99' 'IOS_12'
#  'ANDROID_4.0.2' 'WINDOWSRT_NT 6.3' 'IOS_11.3.1' 'MACINTOSH_OS X'
#  'IOS_9.0.1' 'WINDOWSPHONE_7.0' 'ANDROID_4.0' 'IOS_9.0'
#  'MICROSOFT_WINDOWSME' 'MACINTOSH_OS X 10.5' 'ANDROID_4.1'
#  'ANDROID_8.0ZH-CN' 'MICROSOFT_WINDOWSANDROID10.0' 'ANDROID_7.0.1'
#  'SAILFISH' 'IOS_8.1.1' 'SYMBIANOS_9.1' 'ANDROID_6.1' 'ANDROID_2.2.1'
#  'SUNOSSUN4U' 'MACINTOSH_OS X 10.15' 'ANDROID_9ZH-CN' 'ANDROID_8.0ZH-TW'
#  'MICROSOFT_WIN2000' 'SYMBIANOS_9.4' 'ANDROID_10.2.1' 'ANDROID_7.1'
#  'IOS_8.3' 'IOS_4.0' 'ANDROID_4.1.1' '0' 'IOS_5.1.1' 'IOS_7.0' 'WEBOS'
#  'SYMBIANOS' 'WINDOWSPHONE_8.0' 'IOS_4.1' 'ANDROID_8.0.0EN-US' 'IOS_7.1.1'
#  'IOS_10.0' 'IOS_6.0.2' 'IOS_4.2.1' 'IOS_8.4' 'RIMOS_6.0.0.448'
#  'ANDROID_4.0.1' 'ANDROID_8.0.0ZH-CN' 'IOS_6.0' 'OPENBSD'
#  'WINDOWSMOBILE_10.0' 'ANDROID_6.0.1ZH-CN' 'IOS_8.2' 'IOS_9.1.1'
#  'MACINTOSH_OTHER' 'ANDROID_6.0ZH-CN' 'IOS_7.1.2' 'WINDOWSPHONE_7'
#  'ANDROID_2.3.7' 'NUCLEUSPLUS']

# %% [markdown]
# <h3 id="os_ext"> I create a function that will classify all different variants of each os as the same os for example MICROSOFT_WINDOWS8.1
#
# MICROSOFT_WINXP are to be renamed to MICROSOFT PC</h3>
#     <h3>I do the same for the other types of os including mobile phones, I classify the ones not falling into these main types as others </h3>

# %%
def shortenos(x):
    #print(x)
    if "microsoft" in x.lower().split("_")[0]:
        x="MICROSOFT PC"
        return x
    elif "windowsphone" in x.lower().split("_")[0]:
        x="WINDOWS MOBILE"
        return x
    elif "windowsmobile" in x.lower().split("_")[0]:
        x="WINDOWS MOBILE"
        return x
    elif "macintosh" in x.lower().split("_")[0]:
        x="MACOS PC"
        return x
    elif "ios" in x.lower().split("_")[0]:
        x="IOS PHONE"
        return x
    elif "android" in x.lower().split("_")[0]:
        x="ANDROID"
        return x
    elif "linux" in x.lower().split("_")[0]:
        x="LINUX"
        return x
    elif x.lower()=="notgiven":
        x="NotGiven"
        return x
    else:
        x="OTHER"
        return x
df["os"]=df.operating_sys.apply(shortenos)

# %% [markdown]
# <h3>Now lets groupby the new os column we created and sum the values for VIEWS and VISIT</h3>
# <h3>This will help us in analysing which of these users are belonging to which OS</h3>

# %%
os_df=df.groupby(["os"]).sum().reset_index()
os_df
# Out:
#                os    Unnamed: 0   VISIT  ENGD_VISIT    VIEWS       wk  \
# 0         ANDROID   61939089291  124822       28151   149597  1301520
# 1       IOS PHONE   45202927075   92695       16871   103294   950125
# 2           LINUX   13001138033   33489        8030    39737   272404
# 3        MACOS PC   46572317434   94995       34432   118822   978395
# 4    MICROSOFT PC  380205015829  810167      272009  1061213  7973196
# 5        NotGiven     947605872    1914          99     1998    20020
# 6           OTHER    1815171681    3583        1098     4471    37037
# 7  WINDOWS MOBILE      68878663     157          21      178     1606
#
#        mth          yr
# 0   354960   238888080
# 1   259125   174391125
# 2    74292    49998516
# 3   266835   179579955
# 4  2174508  1463443884
# 5     5460     3674580
# 6    10101     6797973
# 7      438      294774

# %% [markdown]
# <h3 id="views_visits">Lets PLOT! I plotted barplot on the visit and views count you can hover for the value</h3>

# %%
import altair as alt
import altair_render_script
alt.data_transformers.disable_max_rows()
base=alt.Chart(os_df).mark_bar().encode(
x="os",
y="VISIT",
tooltip=["VISIT"]
)

base2=alt.Chart(os_df).mark_bar().encode(
x="os",
y="VIEWS",tooltip=["VIEWS"]
)
alt.hconcat(base,base2)
# Out:
# /kaggle/input/bot-detection/ibm_data.csv
# Define and register the kaggle renderer. Enable with
#
#     alt.renderers.enable('kaggle')
# alt.HConcatChart(...)

# %% [markdown]
# <h1> As we saw microsoft leads in both VISIT and VIEWS as expected of their huge userbase</h1>
# <h3> now comes the hard part...well for me because I did not understand the user agent part until some googling </h3>

# %% [markdown]
# <h1 id="what_ua">What are user agents?</h1>
# <p>Every time your web browser makes a request to a website, it sends a HTTP Header called the "User Agent". The User Agent string contains information about your web browser name, operating system, device type and lots of other useful bits of information.
#
# But every browser sends its user agent in a different format, so decoding them can be very tricky.</p>
# <p>you have many apis and libarries that decode them for you and even tell you if the are<b>a bot or not!</b></p>
# <ul>
#     <li>user-agents from pypi <a href="https://pypi.org/project/user-agents/">  click here</a></li>
#         <li>device-detector(we will use this as it is faster) <a href="https://pypi.org/project/device-detector/">click here</a></li>
#         <li>what is my browser provides apis for this too well it is not free but there are some trial plans which might interest you <a href="https://developers.whatismybrowser.com/useragents/parse/">  click here</a></li></ul>

# %%
df.user_agent.dropna(inplace=True)

# %% [markdown]
# <h1> Installing device detector</h1>

# %%
# !pip install device_detector
# Out:
# Collecting device_detector
#   Downloading device_detector-0.10-py3-none-any.whl (552 kB)
#      |████████████████████████████████| 552 kB 2.7 MB/s eta 0:00:01
# Requirement already satisfied: pyyaml in /opt/conda/lib/python3.7/site-packages (from device_detector) (5.3.1)
# Requirement already satisfied: regex in /opt/conda/lib/python3.7/site-packages (from device_detector) (2020.4.4)
# Installing collected packages: device-detector
# Successfully installed device-detector-0.10

# %% [markdown]
# <h1 id="dd"> you can check the docs over here https://pypi.org/project/device-detector/</h1>
# device = SoftwareDetector(ua).parse()
#
# device.client_name()        # >>> Chrome Mobile
# device.client_short_name()  # >>> CM
# device.client_type()        # >>> browser
# device.client_version()     # >>> 58.0.3029.83
#
# device.os_name()     # >>> Android
# device.os_version()  # >>> 6.0
# device.engine()      # >>> WebKit
#
# device.device_brand_name()  # >>> ''
# device.device_brand()       # >>> ''
# device.device_model()       # >>> ''
# device.device_type()        # >>> ''
#
#
# <h1> WHAT AM I EXTRACTING?</h1>
# <ul>
#     <li>The Browser used</li>
#     <li>The os(although we already have "os" column but I did for the sake of experimenting</li>
#     <li>THE MAIN THING IS IT A BOT????(TRUE AND FALSE)</li>
# </ul>

# %%
from device_detector import SoftwareDetector

# %% [markdown]
# <h1> I create some functions which will be used in apply one will give the client name[browser name] and the other will give out the os name</h1>
# <h1 id="first_half">NOTE:I will be trying these functions on sample data of 400000 as the original dataset takes too much time if you have any recommendation please do tell :D</h1>
# <h1> NOTE: I will then convert this to a csv filer and save it and do the same process on the remaining data and convert that too a csv file too, so 2 csv files will be created and  I will make it public so that we can easily load it without worrying about the user agents parsing </h1>

# %%
def parse_family(x):
    
    return SoftwareDetector(x).parse().client_name()
def parse_os(x):
  
    return SoftwareDetector(x).parse().os_name()

# %% [markdown]
# <h1> here as I stated Ill be taking the 400000 as my sample dataset</h1>

# %%
sample_df=df[:400000]
sample_df.user_agent.dropna(inplace=True)
# Out:
# /opt/conda/lib/python3.7/site-packages/pandas/core/series.py:4494: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._update_inplace(result)

# %% [markdown]
# <h1> The parse family function will parse the browser</h1>

# %%
x=sample_df["user_agent"].apply(parse_family)

# %% [markdown]
# <h1> dropping some null values and the parse os will parse the os</h1>

# %%
sample_df["user_browser"]=x
sample_df.user_agent.dropna(inplace=True)
sample_df["user_os"]=sample_df.user_agent.apply(parse_os)
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
sample_df
# Out:
#         Unnamed: 0      ctry_name intgrtd_mngmt_name  \
# 0                0  United States      United States
# 1                1          Japan              Japan
# 2                2  United States      United States
# 3                3         Brazil             Brazil
# 4                4         France             France
# ...            ...            ...                ...
# 399995      399995  United States      United States
# 399996      399996  United States      United States
# 399997      399997        Germany               DACH
# 399998      399998          Italy              Italy
# 399999      399999          China      Greater China
#
#        intgrtd_operating_team_name                    city  \
# 0                    North America                 SLIDELL
# 1                            Japan                   TOKYO
# 2                    North America               ELK GROVE
# 3                    Latin America  SAO FRANCISCO DE GOIAS
# 4                           Europe                  BEZONS
# ...                            ...                     ...
# 399995               North America                  CAMDEN
# 399996               North America             LOS ANGELES
# 399997                      Europe              NEUOSTHEIM
# 399998                      Europe                 LUNETTA
# 399999         Greater China Group                TANGSHAN
#
#                         st         sec_lvl_domn  device_type  \
# 0                LOUISIANA          CHARTER.COM  MOBILEPHONE
# 1                    TOKYO           MOPERA.NET       TABLET
# 2               CALIFORNIA  COMCASTBUSINESS.NET  MOBILEPHONE
# 3                    GOIAS       VIVOZAP.COM.BR  MOBILEPHONE
# 4               VAL-D'OISE           PROXAD.NET  MOBILEPHONE
# ...                    ...                  ...          ...
# 399995          NEW JERSEY          VERIZON.NET          NaN
# 399996          CALIFORNIA                  NaN        OTHER
# 399997  BADEN-WUERTTEMBERG      CARAT-GRUPPE.DE          NaN
# 399998             MANTOVA             MYNET.IT          NaN
# 399999               HEBEI                  NaN  MOBILEPHONE
#
#               operating_sys  \
# 0                IOS_12.1.4
# 1               ANDROID_6.0
# 2                IOS_12.1.2
# 3               ANDROID_6.0
# 4                 ANDROID_9
# ...                     ...
# 399995  MICROSOFT_WINDOWS10
# 399996                OTHER
# 399997   MICROSOFT_WINDOWS7
# 399998  MICROSOFT_WINDOWS10
# 399999        ANDROID_8.1.0
#
#                                                   ip_addr  ... ENGD_VISIT  \
# 0       287e8e9aeedb50e963906f10cca7ca26ae830154e69220...  ...          0
# 1       d7746df5cc2de7f79584d57c2c082b9acc7697602021a1...  ...          0
# 2       8540464f5f376c7a160d63632f8cbedc96c61158daf9ae...  ...          0
# 3       cb9ffa7be250fc62426a431a4f08bc0c8222f63514ba39...  ...          0
# 4       7ce278be1b02a0253cc0219fa9ceddfe8e91846be343a4...  ...          0
# ...                                                   ...  ...        ...
# 399995  30b77951ff6d3f82bc23144c19ce59c1c1792bd4105eba...  ...          1
# 399996  15ad89bfad51c167a34488ead8d6c07877df2b748fd60d...  ...          0
# 399997  ba4fe7ecb08b3e9c1f127f3a34ee50b523353f82b4069e...  ...          1
# 399998  050668202ee75f6f132deafd0e81dd4304944b3415c8bd...  ...          1
# 399999  e336d4b5623673a0402ddafdd013d41418a171d063b091...  ...          0
#
#         VIEWS                                           page_url  wk mth  \
# 0           1                        www.ibm.com/watson/campaign  11   3
# 1           1                          www.ibm.com/privacy/us/en  11   3
# 2           1  www.ibm.com/account/reg/us-en/signup?formid=ur...  11   3
# 3           1  www.ibm.com/analytics/br/pt/business-intelligence  11   3
# 4           1                           www.ibm.com/watson/fr-fr  11   3
# ...       ...                                                ...  ..  ..
# 399995      1  www.ibm.com/support/knowledgecenter/en/ssd29g_...  11   3
# 399996      1                  www.ibm.com/privacy/details/es/es  11   3
# 399997      1       www.ibm.com/de-de/products/category/business  11   3
# 399998      2  www.ibm.com/partnerworld/commerce/programs/ser...  11   3
# 399999      1                        www-31.ibm.com/ibm/cn/smart  11   3
#
#           yr                  page_vw_ts            os     user_browser  \
# 0       2019  2019-06-04 05:05:18.023100     IOS PHONE    Mobile Safari
# 1       2019  2019-06-04 05:07:11.014300       ANDROID           Chrome
# 2       2019  2019-06-04 05:08:46.081900     IOS PHONE    Mobile Safari
# 3       2019  2019-06-04 05:07:22.033300       ANDROID   Chrome Webview
# 4       2019  2019-06-04 05:05:27.027700       ANDROID   Chrome Webview
# ...      ...                         ...           ...              ...
# 399995  2019  2019-06-04 06:37:25.045000  MICROSOFT PC           Chrome
# 399996  2019  2019-06-04 07:03:33.086800         OTHER  Samsung Browser
# 399997  2019  2019-06-04 07:00:50.074700  MICROSOFT PC          Firefox
# 399998  2019  2019-06-04 06:46:29.068900  MICROSOFT PC           Chrome
# 399999  2019  2019-06-04 07:01:47.049700       ANDROID   Chrome Webview
#
#           user_os
# 0             iOS
# 1         Android
# 2             iOS
# 3         Android
# 4         Android
# ...           ...
# 399995    Windows
# 399996  GNU/Linux
# 399997    Windows
# 399998    Windows
# 399999    Android
#
# [400000 rows x 22 columns]

# %% [markdown]
# <h1 id="is_bot"> Note we import Device Detector below which could have been imported above as well instead of SoftwareDetector,
# but SoftwareDetector detects the software specifically and it faster than device_detector which is said in the docs :D, but device detector below will be needed to classify as bots or not
# </h1>

# %%
from device_detector import DeviceDetector
def parse_is_bot(x):
    return DeviceDetector(x).parse().is_bot()
sample_df.user_agent.dropna(inplace=True)
sample_df["is_bot"]=sample_df["user_agent"].apply(parse_is_bot)
# Out:
# /opt/conda/lib/python3.7/site-packages/pandas/core/series.py:4494: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._update_inplace(result)
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """

# %% [markdown]
# <h1>Some oses were empty because it couldnt be detected so I added unknown string to it</h1>
# <h2>I then group the sample_df by users_os(the one from the User Agent string) and is bot column and use the Count() on each column</h2>

# %%
def replace_empty_user(x):
    if x=="":
       return "Unknown"
    else:
        return x
sample_df["user_os"]=sample_df["user_os"].apply(replace_empty_user)
user_os_df=sample_df.groupby(["user_os","is_bot"]).count().reset_index()
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %% [markdown]
# <h1>Renaming the column unamed to count</h1>

# %%
user_os_df.rename(columns={"Unnamed: 0": "count"},inplace=True)
user_os_df
# Out:
#                  user_os  is_bot   count  ctry_name  intgrtd_mngmt_name  \
# 0                Android   False   45088      45088               45088
# 1                Android    True      26         26                  26
# 2          BlackBerry OS   False      14         14                  14
# 3                 CentOS    True      24         24                  24
# 4              Chrome OS   False     693        693                 693
# 5                 Fedora   False     465        465                 465
# 6                FreeBSD   False       3          3                   3
# 7              GNU/Linux   False    6495       6495                6495
# 8              GNU/Linux    True      31         31                  31
# 9                  KaiOS   False     359        359                 359
# 10                   Mac   False   34064      34064               34064
# 11                  Mint   False       1          1                   1
# 12                  OS/2   False       2          2                   2
# 13             Ordissimo   False       1          1                   1
# 14           PlayStation   False      77         77                  77
# 15           Sailfish OS   False       1          1                   1
# 16               Solaris   False       3          3                   3
# 17               Symbian   False       1          1                   1
# 18  Symbian OS Series 60   False       1          1                   1
# 19                 Tizen   False      63         63                  63
# 20                Ubuntu   False    2589       2589                2589
# 21               Unknown   False     142        142                 142
# 22               Unknown    True     471        471                 471
# 23               Windows   False  276437     276437              276437
# 24         Windows Phone   False      61         61                  61
# 25            Windows RT   False      10         10                  10
# 26                   iOS   False   32864      32864               32864
# 27                   iOS    True      11         11                  11
#
#     intgrtd_operating_team_name    city      st  sec_lvl_domn  device_type  \
# 0                         45088   42723   42786         24783        45076
# 1                            26       2       2            26           26
# 2                            14      14      14             8           14
# 3                            24      24      24             0           24
# 4                           693     685     685           507            0
# 5                           465     461     461           393            0
# 6                             3       3       3             3            0
# 7                          6495    6381    6381          4644           75
# 8                            31       0       0            31            3
# 9                           359     359     359             1          359
# 10                        34064   33435   33451         25702            0
# 11                            1       1       1             1            0
# 12                            2       2       2             2            0
# 13                            1       1       1             1            0
# 14                           77      76      76            69           77
# 15                            1       1       1             1            1
# 16                            3       3       3             3            0
# 17                            1       1       1             1            1
# 18                            1       1       1             1            1
# 19                           63      63      63            40           62
# 20                         2589    2567    2567          1979            0
# 21                          142     140     140           140            2
# 22                          471     471     471           471            0
# 23                       276437  262092  262430        193998           11
# 24                           61      59      59            33           61
# 25                           10      10      10             8           10
# 26                        32864   32561   32578         25600        32863
# 27                           11      10      10             1           11
#
#     ...   VISIT  ENGD_VISIT   VIEWS  page_url      wk     mth      yr  \
# 0   ...   45088       45088   45088     45088   45088   45088   45088
# 1   ...      26          26      26        26      26      26      26
# 2   ...      14          14      14        14      14      14      14
# 3   ...      24          24      24        24      24      24      24
# 4   ...     693         693     693       693     693     693     693
# 5   ...     465         465     465       465     465     465     465
# 6   ...       3           3       3         3       3       3       3
# 7   ...    6495        6495    6495      6495    6495    6495    6495
# 8   ...      31          31      31        31      31      31      31
# 9   ...     359         359     359       359     359     359     359
# 10  ...   34064       34064   34064     34064   34064   34064   34064
# 11  ...       1           1       1         1       1       1       1
# 12  ...       2           2       2         2       2       2       2
# 13  ...       1           1       1         1       1       1       1
# 14  ...      77          77      77        77      77      77      77
# 15  ...       1           1       1         1       1       1       1
# 16  ...       3           3       3         3       3       3       3
# 17  ...       1           1       1         1       1       1       1
# 18  ...       1           1       1         1       1       1       1
# 19  ...      63          63      63        63      63      63      63
# 20  ...    2589        2589    2589      2589    2589    2589    2589
# 21  ...     142         142     142       142     142     142     142
# 22  ...     471         471     471       471     471     471     471
# 23  ...  276437      276437  276437    276436  276437  276437  276437
# 24  ...      61          61      61        61      61      61      61
# 25  ...      10          10      10        10      10      10      10
# 26  ...   32864       32864   32864     32864   32864   32864   32864
# 27  ...      11          11      11        11      11      11      11
#
#     page_vw_ts      os  user_browser
# 0        44979   45088         45088
# 1           26      26            26
# 2           14      14            14
# 3           24      24            24
# 4          693     693           693
# 5          462     465           465
# 6            3       3             3
# 7         6480    6495          6495
# 8           31      31            31
# 9          357     359           359
# 10       33973   34064         34064
# 11           1       1             1
# 12           2       2             2
# 13           1       1             1
# 14          75      77            77
# 15           1       1             1
# 16           3       3             3
# 17           1       1             1
# 18           1       1             1
# 19          63      63            63
# 20        2582    2589          2589
# 21         141     142           142
# 22         471     471           471
# 23      275773  276437        276437
# 24          61      61            61
# 25          10      10            10
# 26       32760   32864         32864
# 27          11      11            11
#
# [28 rows x 23 columns]

# %% [markdown]
# <h1 id="plot_is_bot"> Plotting 2 barplots one for bots detected and one for not bots hover for more info</h1>

# %%
base=alt.Chart(user_os_df[user_os_df.is_bot==True]).mark_bar().encode(
x="user_os",
y="count",
    tooltip=["count"]
).properties(title="BOTS")

base1=alt.Chart(user_os_df[user_os_df.is_bot==False]).mark_bar().encode(
x="user_os",
y="count",
     tooltip=["count"]
).properties(title="Not_BOTS")
alt.hconcat(base,base1)
# Out:
# alt.HConcatChart(...)

# %% [markdown]
# <h1 id="is_bot_browser"> We do the same but instead of user os we count for browser</h1>
# <h1>NOTE: There are some browser names parsed by the parse like _CT_OBJ...etc I do not have much information about them If you have any knowledge or info about them please do comment :D</h1>

# %%
browser_df=sample_df.groupby(["user_browser","is_bot"]).count().reset_index()
browser_df.rename(columns={"Unnamed: 0": "count"},inplace=True)

base=alt.Chart(browser_df[browser_df.is_bot==True]).mark_bar().encode(
x="user_browser",
y="count",
    tooltip=["count"]
).properties(title="BOTS")

base1=alt.Chart(browser_df[browser_df.is_bot==False]).mark_bar().encode(
x="user_browser",
y="count",
     tooltip=["count"]
).properties(title="Not_BOTS")
alt.hconcat(base,base1)
# Out:
# alt.HConcatChart(...)

# %% [markdown]
# <h2 id="tocsv1"> I convert this dataframe to first half csv which I will be planning to use in other notebooks </h2>

# %%
sample_df.to_csv("bots_firsthalf.csv",index=False)

# %% [markdown]
# <h2> Now the same procedure for the rest of the data</h2>

# %%
sample_df2=df[400000:]
sample_df2.user_agent.dropna(inplace=True)
x=sample_df2["user_agent"].apply(parse_family)
sample_df2["user_browser"]=x
sample_df2.user_agent.dropna(inplace=True)
sample_df2["user_os"]=sample_df2.user_agent.apply(parse_os)
# Out:
# /opt/conda/lib/python3.7/site-packages/pandas/core/series.py:4494: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._update_inplace(result)
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
sample_df2.user_agent.dropna(inplace=True)
sample_df2["is_bot"]=sample_df2["user_agent"].apply(parse_is_bot)
# Out:
# /opt/conda/lib/python3.7/site-packages/pandas/core/series.py:4494: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._update_inplace(result)
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %% [markdown]
# <h1 id="secondhalf">The secondHalf of the cvs</h1>

# %%
sample_df.to_csv("bots_secondhalf.csv",index=False)

# %% [markdown]
# * <h1 id="big"> concatenate both dataframe to the original big dataframe and then save that dataframe as a csv</h1>

# %%
the_big_df=pd.concat([sample_df,sample_df2])

# %%
the_big_df.to_csv("bots_full.csv",index=False)

# %% [markdown]
# <h1 id="conclusion"> TO BE CONTINUED!!! I WILL WORK ON A NEW NOTEBOOK OTHER THAN THIS STAY TUNED!!</h1>

# %%
# Out:
# (1048573, 20)
